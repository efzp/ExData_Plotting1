# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

tf.random.set_seed(0)

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    h = 0.05
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:,0], X[:,1], c=y.ravel(), cmap=plt.cm.Spectral)

def plot_history(history: tf.keras.callbacks.History) -> None:
    """Plot training and validation loss/accuracy curves."""
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    axes[0].plot(history.history['loss'], label='train')
    axes[0].plot(history.history['val_loss'], label='val')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()

    axes[1].plot(history.history['accuracy'], label='train')
    axes[1].plot(history.history['val_accuracy'], label='val')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout()

def load_planar_dataset(m, sigma=0.2):
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*sigma # theta
        r = a*np.sin(4*t) + np.random.randn(N)*sigma # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j

    ## premuting ouput
    p = np.random.permutation(m)
    X = X[p,:]
    Y = Y[p,:]

    return X, Y.ravel()

def draw_neural_net(left, right, bottom, top, layer_sizes):
    '''
    From https://gist.github.com/craffel/2d727968c3aaebd10359#file-draw_neural_net-py
    Draw a neural network cartoon using matplotilb.

    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])

    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    fig = plt.figure(figsize=(3, 3))
    ax = fig.gca()
    ax.axis('off')

    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %% [markdown]
# ## Dataset
#
# We have a binary classification dataset. The target `y` has two possible values, {0,1} and the input vector `x` has two dimensions.

# %%
N = 5000
X, y = load_planar_dataset(N, 0.2)

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.2,
)

# %%
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(4000, 2), y_train shape:(4000,)
# X_test shape:(1000, 2), y_test shape:(1000,)

# %%
## X first example
X[0,:]
# Out:
# array([ 1.57106342, -3.38875926])

# %%
## Y firsts examples
y[:8]
# Out:
# array([1, 1, 1, 0, 1, 1, 0, 0], dtype=uint8)

# %% [markdown]
# ## First NN in Keras
#
# ### Logistic regression
#
# Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class. We can specify the number of neurons as the first argument, and specify the activation function using the activation argument.
#
# ```python
# tf.keras.layers.Dense(
#     units, activation=None
# )
#
# ```
#
# - **units**: Number of neurons in the layer.
# - **activation**: Activation function to use, default function is `linear`, you can also use `sigmoid` for sigmoid activation or [other alternatives](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# For defining the input layer you have two options:
#
# **Option 1**: Use `keras.Input(shape=(input_dimension,))` as the first layer:
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2,)),
#     layers.Dense(4, activation="sigmoid"),
#     layers.Dense(1, activation="sigmoid")
# ])
# ```
#
# **Option 2**: Define `input_shape` in the first hidden layer:
# ```python
# model = keras.Sequential([
#     layers.Dense(4, activation="sigmoid", input_shape=(2,)),
#     layers.Dense(1, activation="sigmoid")
# ])
# ```
#
# Both approaches are equivalent. Using `keras.Input` is more explicit and recommended for complex models.
#
# Build a network without hidden layer

# %%
draw_neural_net(.1, .9, .1, .9, [2, 1])

# %%
model = keras.Sequential()
# The dimension of the input is 2 (planar data)
# we have only one output layer with 1 neuron
# Alternative: model.add(keras.Input(shape=(2,))) then model.add(Dense(1, activation='sigmoid'))
model.add(keras.layers.Dense(1, input_shape=(2, ), activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# #### Compile
# Now we need to specify the loss function, the metrics and the optimizer. It is done using compile function in Keras.
#
# - **loss='binary_crossentropy'**: Loss function for binary classification. Measures how well predicted probabilities match true labels (0 or 1).
# - **optimizer='adam'**: Adaptive learning rate optimizer that combines momentum and RMSprop. Works well in most cases.
# - **metrics=['accuracy']**: Metrics to monitor during training.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Training model
# This is similar to a sklearn model.
#
# - **epochs**: Number of complete passes through the training data.
# - **batch_size**: Number of samples processed before updating weights.
# - **validation_split**: Fraction of training data used to monitor performance during training.

# %%
model.fit(X_train, y_train, epochs=10,
          validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5013 - loss: 0.7046 - val_accuracy: 0.4913 - val_loss: 0.6875
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4928 - loss: 0.6849 - val_accuracy: 0.4825 - val_loss: 0.6725
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4787 - loss: 0.6718 - val_accuracy: 0.4787 - val_loss: 0.6631
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4719 - loss: 0.6637 - val_accuracy: 0.4800 - val_loss: 0.6577
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4709 - loss: 0.6593 - val_accuracy: 0.4775 - val_loss: 0.6550
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4703 - loss: 0.6571 - val_accuracy: 0.4775 - val_loss: 0.6538
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4716 - loss: 0.6562 - val_accuracy: 0.4787 - val_loss: 0.6533
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4719 - loss: 0.6557 - val_accuracy: 0.4812 - val_loss: 0.6532
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4722 - loss: 0.6556 - val_accuracy: 0.4812 - val_loss: 0.6531
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4716 - loss: 0.6555 - val_accuracy: 0.4800 - val_loss: 0.6531

# %% [markdown]
# #### Making predictions

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6722759008407593
# Test Accuracy: 0.44200000166893005

# %%
y_pred = model.predict(X_test)
y_pred[:3], y_test[:3]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (array([[0.5659711 ],
#         [0.61565995],
#         [0.4129348 ]], dtype=float32),
#  array([0, 1, 1], dtype=uint8))

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("Basic NN");
# Out:
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step

# %% [markdown]
# ### One hidden layer NN
#
# - One **input with 2 features (input_shape)**
# - **One hidden dense layer**,  with **3 neurons** and implemented with  **sigmoid activating function**
# - **One Output** (sigmoid output activation function)
#
# We can create layers incrementally with the method `add()`:

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 1])

# %%
model = keras.Sequential()

## hidden layer with 3 neurons and sigmoid activation
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

## model summary
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# You can also define the model with a list of layers
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2, )),
#     layers.Dense(3, activation='sigmoid', name='layer1'),
#     layers.Dense(1, activation='sigmoid', name='layer3')
# ])
# ````

# %%
plot_model(model, show_shapes=True)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
plot_history(history)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5275 - loss: 0.6965 - val_accuracy: 0.5788 - val_loss: 0.6889
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5669 - loss: 0.6897 - val_accuracy: 0.6000 - val_loss: 0.6826
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5978 - loss: 0.6841 - val_accuracy: 0.6375 - val_loss: 0.6772
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6244 - loss: 0.6791 - val_accuracy: 0.6600 - val_loss: 0.6723
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 0.6745 - val_accuracy: 0.6650 - val_loss: 0.6678
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6422 - loss: 0.6703 - val_accuracy: 0.6737 - val_loss: 0.6635
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6434 - loss: 0.6665 - val_accuracy: 0.6725 - val_loss: 0.6595
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6438 - loss: 0.6628 - val_accuracy: 0.6650 - val_loss: 0.6558
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6441 - loss: 0.6594 - val_accuracy: 0.6612 - val_loss: 0.6522
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.6562 - val_accuracy: 0.6600 - val_loss: 0.6488
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6447 - loss: 0.6532 - val_accuracy: 0.6625 - val_loss: 0.6456
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6450 - loss: 0.6503 - val_accuracy: 0.6625 - val_loss: 0.6425
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6469 - loss: 0.6476 - val_accuracy: 0.6650 - val_loss: 0.6397
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6469 - loss: 0.6451 - val_accuracy: 0.6650 - val_loss: 0.6370
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6472 - loss: 0.6427 - val_accuracy: 0.6625 - val_loss: 0.6344
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6488 - loss: 0.6404 - val_accuracy: 0.6637 - val_loss: 0.6320
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6481 - loss: 0.6382 - val_accuracy: 0.6637 - val_loss: 0.6297
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6491 - loss: 0.6362 - val_accuracy: 0.6700 - val_loss: 0.6275
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6342 - val_accuracy: 0.6700 - val_loss: 0.6254
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6506 - loss: 0.6323 - val_accuracy: 0.6700 - val_loss: 0.6235
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6513 - loss: 0.6305 - val_accuracy: 0.6700 - val_loss: 0.6216
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6519 - loss: 0.6288 - val_accuracy: 0.6700 - val_loss: 0.6198
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6522 - loss: 0.6272 - val_accuracy: 0.6700 - val_loss: 0.6180
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6525 - loss: 0.6256 - val_accuracy: 0.6700 - val_loss: 0.6164
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6528 - loss: 0.6241 - val_accuracy: 0.6700 - val_loss: 0.6148

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6357446908950806
# Test Accuracy: 0.6290000081062317

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN");
# Out:
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 1:
# ####  What happens if we change the activation function of the first hidden  layer to `'linear'`?

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='linear'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4953 - loss: 1.3424 - val_accuracy: 0.5138 - val_loss: 1.2177
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5312 - loss: 1.1025 - val_accuracy: 0.5288 - val_loss: 1.0260
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5294 - loss: 0.9525 - val_accuracy: 0.5238 - val_loss: 0.9062
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5138 - loss: 0.8596 - val_accuracy: 0.5000 - val_loss: 0.8307
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4997 - loss: 0.8005 - val_accuracy: 0.4863 - val_loss: 0.7815
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4878 - loss: 0.7612 - val_accuracy: 0.4800 - val_loss: 0.7478
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4756 - loss: 0.7336 - val_accuracy: 0.4762 - val_loss: 0.7234
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4581 - loss: 0.7132 - val_accuracy: 0.4913 - val_loss: 0.7049
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4169 - loss: 0.6974 - val_accuracy: 0.5250 - val_loss: 0.6903
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5291 - loss: 0.6850 - val_accuracy: 0.4938 - val_loss: 0.6789
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4869 - loss: 0.6753 - val_accuracy: 0.4875 - val_loss: 0.6701
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4769 - loss: 0.6681 - val_accuracy: 0.4837 - val_loss: 0.6637
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4750 - loss: 0.6630 - val_accuracy: 0.4837 - val_loss: 0.6593
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4734 - loss: 0.6597 - val_accuracy: 0.4825 - val_loss: 0.6566
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4719 - loss: 0.6577 - val_accuracy: 0.4825 - val_loss: 0.6551
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4719 - loss: 0.6567 - val_accuracy: 0.4825 - val_loss: 0.6542
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4709 - loss: 0.6562 - val_accuracy: 0.4825 - val_loss: 0.6538
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4706 - loss: 0.6559 - val_accuracy: 0.4825 - val_loss: 0.6536
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4706 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6536
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4709 - loss: 0.6558 - val_accuracy: 0.4825 - val_loss: 0.6535

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6717267632484436
# Test Accuracy: 0.4410000145435333
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 2:
# ####  What happens if we add more neurons to the first hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 5, 1])

# %%
model = keras.Sequential()

## The first layer need to have the input_shape
## set the number of neurons
model.add(layers.Dense(6, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6691 - loss: 0.6633 - val_accuracy: 0.6550 - val_loss: 0.6553
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6366 - loss: 0.6542 - val_accuracy: 0.6263 - val_loss: 0.6470
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6141 - loss: 0.6465 - val_accuracy: 0.5975 - val_loss: 0.6397
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5881 - loss: 0.6395 - val_accuracy: 0.5713 - val_loss: 0.6330
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5606 - loss: 0.6329 - val_accuracy: 0.5312 - val_loss: 0.6268
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5337 - loss: 0.6268 - val_accuracy: 0.5113 - val_loss: 0.6209
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5119 - loss: 0.6211 - val_accuracy: 0.4913 - val_loss: 0.6155
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4972 - loss: 0.6157 - val_accuracy: 0.4875 - val_loss: 0.6103
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4872 - loss: 0.6106 - val_accuracy: 0.4825 - val_loss: 0.6054
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4828 - loss: 0.6058 - val_accuracy: 0.4800 - val_loss: 0.6008
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4766 - loss: 0.6012 - val_accuracy: 0.4787 - val_loss: 0.5964
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4791 - loss: 0.5967 - val_accuracy: 0.4950 - val_loss: 0.5922
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5003 - loss: 0.5924 - val_accuracy: 0.5325 - val_loss: 0.5880
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5466 - loss: 0.5881 - val_accuracy: 0.5512 - val_loss: 0.5838
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6025 - loss: 0.5839 - val_accuracy: 0.6150 - val_loss: 0.5797
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6466 - loss: 0.5795 - val_accuracy: 0.6700 - val_loss: 0.5753
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6794 - loss: 0.5749 - val_accuracy: 0.6862 - val_loss: 0.5708
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7053 - loss: 0.5701 - val_accuracy: 0.7088 - val_loss: 0.5660
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7244 - loss: 0.5650 - val_accuracy: 0.7225 - val_loss: 0.5609
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7409 - loss: 0.5596 - val_accuracy: 0.7462 - val_loss: 0.5555
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7603 - loss: 0.5539 - val_accuracy: 0.7650 - val_loss: 0.5499
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7725 - loss: 0.5480 - val_accuracy: 0.7763 - val_loss: 0.5441
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7825 - loss: 0.5419 - val_accuracy: 0.7862 - val_loss: 0.5381
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.5357 - val_accuracy: 0.7925 - val_loss: 0.5321
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.5294 - val_accuracy: 0.8062 - val_loss: 0.5260

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, more neurons");
# Out:
# Test Loss: 0.5464487075805664
# Test Accuracy: 0.7760000228881836
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 3:
# ####  What happens if we add one more hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 3, 1])

# %%
model = keras.Sequential()
# First hidden layer (need to innclude input_shape)
## Set the number of neurons
model.add(layers.Dense(10, input_shape=(2,), activation='sigmoid'))

# second hidden layer
## Complete the code
model.add(layers.Dense(20, activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8584 - loss: 0.4108 - val_accuracy: 0.8625 - val_loss: 0.4055
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8634 - loss: 0.3955 - val_accuracy: 0.8675 - val_loss: 0.3917
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.3821 - val_accuracy: 0.8675 - val_loss: 0.3797
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8728 - loss: 0.3705 - val_accuracy: 0.8750 - val_loss: 0.3692
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8769 - loss: 0.3604 - val_accuracy: 0.8737 - val_loss: 0.3602
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8781 - loss: 0.3517 - val_accuracy: 0.8763 - val_loss: 0.3524
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8800 - loss: 0.3442 - val_accuracy: 0.8763 - val_loss: 0.3457
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8822 - loss: 0.3376 - val_accuracy: 0.8775 - val_loss: 0.3398
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8850 - loss: 0.3319 - val_accuracy: 0.8813 - val_loss: 0.3346
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8866 - loss: 0.3268 - val_accuracy: 0.8850 - val_loss: 0.3301
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8878 - loss: 0.3223 - val_accuracy: 0.8888 - val_loss: 0.3261
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8894 - loss: 0.3183 - val_accuracy: 0.8938 - val_loss: 0.3225
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8891 - loss: 0.3147 - val_accuracy: 0.8863 - val_loss: 0.3193
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.3115 - val_accuracy: 0.8775 - val_loss: 0.3165
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.3085 - val_accuracy: 0.8775 - val_loss: 0.3139
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8919 - loss: 0.3059 - val_accuracy: 0.8800 - val_loss: 0.3116
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8906 - loss: 0.3035 - val_accuracy: 0.8763 - val_loss: 0.3094
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.3013 - val_accuracy: 0.8763 - val_loss: 0.3075
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.2992 - val_accuracy: 0.8763 - val_loss: 0.3057
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.2974 - val_accuracy: 0.8763 - val_loss: 0.3041
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.2956 - val_accuracy: 0.8763 - val_loss: 0.3027
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8916 - loss: 0.2940 - val_accuracy: 0.8800 - val_loss: 0.3013
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8916 - loss: 0.2925 - val_accuracy: 0.8825 - val_loss: 0.3000
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8919 - loss: 0.2911 - val_accuracy: 0.8825 - val_loss: 0.2988
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8919 - loss: 0.2898 - val_accuracy: 0.8850 - val_loss: 0.2977

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("2 Hidden layers NN");
# Out:
# Test Loss: 0.3000997304916382
# Test Accuracy: 0.8880000114440918
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ####  Use  the [hyperbolic tangent](https://mathworld.wolfram.com/HyperbolicTangent.html) activation `'tanh'` with the first simple model and compare the results with the sigmoid activation

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='tanh'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4728 - loss: 0.9376 - val_accuracy: 0.4950 - val_loss: 0.8845
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4894 - loss: 0.8425 - val_accuracy: 0.5075 - val_loss: 0.8012
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4978 - loss: 0.7668 - val_accuracy: 0.5038 - val_loss: 0.7387
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5428 - loss: 0.7162 - val_accuracy: 0.5738 - val_loss: 0.7019
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6256 - loss: 0.6880 - val_accuracy: 0.6325 - val_loss: 0.6802
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6844 - loss: 0.6702 - val_accuracy: 0.6825 - val_loss: 0.6640
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6241 - loss: 0.6567 - val_accuracy: 0.6012 - val_loss: 0.6516
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5728 - loss: 0.6470 - val_accuracy: 0.5650 - val_loss: 0.6426
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5406 - loss: 0.6395 - val_accuracy: 0.5475 - val_loss: 0.6351
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5191 - loss: 0.6326 - val_accuracy: 0.5362 - val_loss: 0.6279
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4991 - loss: 0.6259 - val_accuracy: 0.5125 - val_loss: 0.6209
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4856 - loss: 0.6192 - val_accuracy: 0.5013 - val_loss: 0.6141
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4828 - loss: 0.6129 - val_accuracy: 0.5050 - val_loss: 0.6078
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4938 - loss: 0.6069 - val_accuracy: 0.5188 - val_loss: 0.6020
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5109 - loss: 0.6015 - val_accuracy: 0.5425 - val_loss: 0.5966
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5234 - loss: 0.5964 - val_accuracy: 0.5437 - val_loss: 0.5918
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5362 - loss: 0.5919 - val_accuracy: 0.5525 - val_loss: 0.5874
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5550 - loss: 0.5877 - val_accuracy: 0.5650 - val_loss: 0.5834
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5681 - loss: 0.5838 - val_accuracy: 0.5750 - val_loss: 0.5796
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5772 - loss: 0.5801 - val_accuracy: 0.5875 - val_loss: 0.5761
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5878 - loss: 0.5765 - val_accuracy: 0.5925 - val_loss: 0.5725
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6012 - loss: 0.5728 - val_accuracy: 0.6075 - val_loss: 0.5688
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6400 - loss: 0.5688 - val_accuracy: 0.6488 - val_loss: 0.5646
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7131 - loss: 0.5641 - val_accuracy: 0.7412 - val_loss: 0.5595
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7412 - loss: 0.5583 - val_accuracy: 0.7588 - val_loss: 0.5531

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, tanh activation");
# Out:
# Test Loss: 0.5772772431373596
# Test Accuracy: 0.7409999966621399
# 1333/1333 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Practice I
#
# Repeat the process with a different dataset.

# %%
N = 5000
X, y = sklearn.datasets.make_moons(n_samples=N, noise=.18)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

## Second Layer, don't use input_shape
model.add(layers.Dense(15 , activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4897 - loss: 0.7852 - val_accuracy: 0.5093 - val_loss: 0.7310
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4897 - loss: 0.7192 - val_accuracy: 0.5093 - val_loss: 0.6982
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4897 - loss: 0.6935 - val_accuracy: 0.5093 - val_loss: 0.6842
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6670 - loss: 0.6791 - val_accuracy: 0.8333 - val_loss: 0.6721
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8420 - loss: 0.6658 - val_accuracy: 0.8373 - val_loss: 0.6589
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8490 - loss: 0.6515 - val_accuracy: 0.8440 - val_loss: 0.6441
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8483 - loss: 0.6358 - val_accuracy: 0.8440 - val_loss: 0.6279
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8480 - loss: 0.6186 - val_accuracy: 0.8440 - val_loss: 0.6101
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8487 - loss: 0.5999 - val_accuracy: 0.8440 - val_loss: 0.5907
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8477 - loss: 0.5796 - val_accuracy: 0.8413 - val_loss: 0.5699
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8473 - loss: 0.5579 - val_accuracy: 0.8413 - val_loss: 0.5478
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8463 - loss: 0.5352 - val_accuracy: 0.8387 - val_loss: 0.5247
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.5117 - val_accuracy: 0.8373 - val_loss: 0.5011
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8450 - loss: 0.4881 - val_accuracy: 0.8360 - val_loss: 0.4775
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8467 - loss: 0.4647 - val_accuracy: 0.8360 - val_loss: 0.4546
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8470 - loss: 0.4424 - val_accuracy: 0.8373 - val_loss: 0.4328
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8480 - loss: 0.4216 - val_accuracy: 0.8387 - val_loss: 0.4128
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8487 - loss: 0.4028 - val_accuracy: 0.8427 - val_loss: 0.3948
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8493 - loss: 0.3861 - val_accuracy: 0.8440 - val_loss: 0.3790
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8510 - loss: 0.3717 - val_accuracy: 0.8440 - val_loss: 0.3652
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8550 - loss: 0.3593 - val_accuracy: 0.8467 - val_loss: 0.3534
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8560 - loss: 0.3488 - val_accuracy: 0.8507 - val_loss: 0.3432
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.3399 - val_accuracy: 0.8520 - val_loss: 0.3344
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8580 - loss: 0.3323 - val_accuracy: 0.8547 - val_loss: 0.3269
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8620 - loss: 0.3259 - val_accuracy: 0.8560 - val_loss: 0.3203
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8640 - loss: 0.3205 - val_accuracy: 0.8587 - val_loss: 0.3147
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8640 - loss: 0.3159 - val_accuracy: 0.8613 - val_loss: 0.3098
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8663 - loss: 0.3120 - val_accuracy: 0.8627 - val_loss: 0.3055
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.3087 - val_accuracy: 0.8640 - val_loss: 0.3019
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8677 - loss: 0.3060 - val_accuracy: 0.8640 - val_loss: 0.2987
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8677 - loss: 0.3037 - val_accuracy: 0.8653 - val_loss: 0.2960
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8697 - loss: 0.3018 - val_accuracy: 0.8653 - val_loss: 0.2938
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8700 - loss: 0.3002 - val_accuracy: 0.8653 - val_loss: 0.2918
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8707 - loss: 0.2990 - val_accuracy: 0.8653 - val_loss: 0.2901
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8693 - loss: 0.2979 - val_accuracy: 0.8667 - val_loss: 0.2887

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.29066169261932373
# Test Accuracy: 0.8736000061035156
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Saving and Loading Keras Models
#
# You can easily save your entire model (architecture, weights, and optimizer state) in a single call using either `.keras` or `.h5` formats.
#
# - **`.keras`**: The default and recommended format from TensorFlow 2.12 onwards. It includes comprehensive model metadata and is future-proof.
# - **`.h5`**: An older HDF5 format that is still widely used due to its simplicity and compatibility.

# %%
import datetime

# Save model with timestamp
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model_name_keras = f"keras_model_{current_time}.keras"
model_name_h5 = f"keras_model_{current_time}.h5"

# Save in .keras format (recommended for TensorFlow/Keras > 2.12)
model.save(model_name_keras)

# Alternatively, save in .h5 format
model.save(model_name_h5)

print(f"Models saved as: {model_name_keras} and {model_name_h5}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved as: keras_model_20260508-170438.keras and keras_model_20260508-170438.h5

# %%
# List files in current directory
# !ls -l
# Out:
# total 100
# -rw-r--r-- 1 root root 33128 May  8 17:04 keras_model_20260508-170438.h5
# -rw-r--r-- 1 root root 26561 May  8 17:04 keras_model_20260508-170438.keras
# -rw-r--r-- 1 root root 30749 May  8 16:37 model.png
# drwxr-xr-x 1 root root  4096 Apr 16 13:28 sample_data

# %%
from tensorflow.keras.models import load_model

# Load your previously saved model
loaded_model = load_model(model_name_keras)  # or .h5

# Evaluate loaded model
loss, accuracy = loaded_model.evaluate(X_test, y_test)
print(f"Loaded model accuracy: {accuracy*100:.2f}%")
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8736 - loss: 0.2907
# Loaded model accuracy: 87.36%

# %% [markdown]
# ### Question 4: Train 10 epochs, save the model, load it, and then train 10 more epochs

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(2, input_shape=(...,), activation=...))

## Second Layer, don't use input_shape
model...(...)

# output layer
model.add(layers.Dense(..., activation=...))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %%
# Save the model
model_name = ...
model.save(...

# %%
# load the model

# %%
# Train the model 10 more epochs
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %% [markdown]
# ## Functional API
#
# The Keras Functional API allows defining the topology of the models as a [acyclic directed graph](https://en.wikipedia.org/wiki/Directed_acyclic_graph) of layers. Next we will build the same model as in the previous section but using the Keras Functional API.
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
# ```
#
# We define the layers that we will include in the network and the relationships between them. It is important to note that each line details the type of layer and its properties (number of neurons, activation function, name ...) and just at the end, in parentheses, the name of the variable in which we have saved the layer from which its output will connect to the input of the layer we are declaring.
# ```python
# layer_1 = layers.Dense(4, activation='sigmoid',
#                        name='layer_1')(inputs)
# layer_2 = layers.Dense(4, activation='sigmoid',
#                        name='layer_2')(layer_1)
# ```
#
# The "layer call" `Dense()(inputs)` action is like drawing an arrow from "inputs" to this layer you created. You're "passing" the inputs to the dense layer, and you get `layer_1` as the output.
#
#
#
# Finally, we define the network outputs:
# ```python
# outputs = layers.Dense(1, name='output_layer')(layer_2)
# ```
#
# We create the model specifying the inputs and outputs:
# ```python
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```

# %%
draw_neural_net(.1, .9, .1, .9, [8, 4, 4, 1])

# %%
inputs = keras.Input(shape=(8, ), name='input_layer')
l_1 = layers.Dense(4, activation='relu', name='layer_1')(inputs)
l_2 = layers.Dense(4, activation='relu', name='layer_2')(l_1)
outputs = layers.Dense(1, activation="sigmoid", name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()
# Out:
# Model: "example_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Practice II
#
# Repeat the process with a different dataset and the **Functional API**

# %%
N = 5000
X, y = sklearn.datasets.make_circles(n_samples=N, factor=.65, noise=.065) # sklearn.datasets.make_moons(n_samples=N, noise=.15)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))

# %% [markdown]
# ### Define your model

# %%
inputs = keras.Input(shape=(2, ), name='input_layer')
## First hidden layer
l_1 = layers.Dense(1, 'sigmoid')(inputs)
l_2 = layers.Dense(15, 'sigmoid')(l_1)

## output layer
outputs = layers.Dense(1, 'sigmoid')(l_2)


model = keras.Model(inputs=inputs,outputs=outputs)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4897 - loss: 0.7338 - val_accuracy: 0.5093 - val_loss: 0.7041
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4897 - loss: 0.7008 - val_accuracy: 0.5093 - val_loss: 0.6929
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4907 - loss: 0.6920 - val_accuracy: 0.5360 - val_loss: 0.6885
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7807 - loss: 0.6864 - val_accuracy: 0.8600 - val_loss: 0.6822
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8433 - loss: 0.6791 - val_accuracy: 0.8667 - val_loss: 0.6737
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8607 - loss: 0.6699 - val_accuracy: 0.8693 - val_loss: 0.6635
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.6591 - val_accuracy: 0.8747 - val_loss: 0.6518
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8697 - loss: 0.6468 - val_accuracy: 0.8707 - val_loss: 0.6388
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8690 - loss: 0.6331 - val_accuracy: 0.8680 - val_loss: 0.6246
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8660 - loss: 0.6183 - val_accuracy: 0.8667 - val_loss: 0.6093
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8650 - loss: 0.6025 - val_accuracy: 0.8640 - val_loss: 0.5931
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8623 - loss: 0.5858 - val_accuracy: 0.8627 - val_loss: 0.5761
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8603 - loss: 0.5683 - val_accuracy: 0.8600 - val_loss: 0.5586
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8587 - loss: 0.5504 - val_accuracy: 0.8587 - val_loss: 0.5407
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8570 - loss: 0.5323 - val_accuracy: 0.8520 - val_loss: 0.5226
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8563 - loss: 0.5142 - val_accuracy: 0.8507 - val_loss: 0.5048
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8560 - loss: 0.4963 - val_accuracy: 0.8507 - val_loss: 0.4873
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8557 - loss: 0.4790 - val_accuracy: 0.8480 - val_loss: 0.4704
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8550 - loss: 0.4624 - val_accuracy: 0.8480 - val_loss: 0.4543
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8550 - loss: 0.4467 - val_accuracy: 0.8453 - val_loss: 0.4391
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8550 - loss: 0.4320 - val_accuracy: 0.8453 - val_loss: 0.4249
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8550 - loss: 0.4184 - val_accuracy: 0.8453 - val_loss: 0.4118
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8560 - loss: 0.4059 - val_accuracy: 0.8453 - val_loss: 0.3998
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8567 - loss: 0.3945 - val_accuracy: 0.8493 - val_loss: 0.3888
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.3841 - val_accuracy: 0.8520 - val_loss: 0.3788
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8567 - loss: 0.3748 - val_accuracy: 0.8520 - val_loss: 0.3697
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.3663 - val_accuracy: 0.8533 - val_loss: 0.3614
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8577 - loss: 0.3587 - val_accuracy: 0.8547 - val_loss: 0.3539
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8587 - loss: 0.3519 - val_accuracy: 0.8547 - val_loss: 0.3471
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8620 - loss: 0.3458 - val_accuracy: 0.8547 - val_loss: 0.3409
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8630 - loss: 0.3402 - val_accuracy: 0.8560 - val_loss: 0.3353
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8637 - loss: 0.3353 - val_accuracy: 0.8587 - val_loss: 0.3301
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8640 - loss: 0.3308 - val_accuracy: 0.8587 - val_loss: 0.3255
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8640 - loss: 0.3268 - val_accuracy: 0.8627 - val_loss: 0.3213
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.3232 - val_accuracy: 0.8627 - val_loss: 0.3175

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.31430384516716003
# Test Accuracy: 0.8623999953269958
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Visualize decision boundary by epoch

# %%
from sklearn.preprocessing import StandardScaler
from IPython.display import Image
import os

# %%
def plot_save_decision_boundary(model, X, y, epoch, epoch_image):
    h = 0.1
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    X_grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(X_grid)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.5, colors=['blue', 'red'], levels=[-0.5, 0.5, 1.5])
    plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0', alpha=0.5)
    plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1', alpha=0.5)
    plt.title(f'Epoch {epoch}')
    plt.savefig(epoch_image)
    plt.close()

def generate_spiral_dataset(n_points, noise=0.5):
    n = np.sqrt(np.random.rand(n_points, 1)) * 780 * (2 * np.pi) / 360
    d1x = -np.cos(n) * n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n) * n + np.random.rand(n_points, 1) * noise

    X, y = (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))))
    return X, y.reshape(-1, 1)

n_points = 2500
X, y = generate_spiral_dataset(n_points)

# %%
plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0')
plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1')
plt.legend()
plt.show()

# %%
# Normalize data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

n_epochs = 60
epoch_images = []

for epoch in range(n_epochs):
    model.fit(X_train, y_train, epochs=1, verbose=0)
    epoch_image = f'epoch_{epoch}.png'
    epoch_images.append(epoch_image)

    plot_save_decision_boundary(model, X_test, y_test, epoch, epoch_image)

# %%
from PIL import Image as Image_PIL

# Create the GIF
gif_filename = 'epoch_animation.gif'
images = [Image_PIL.open(epoch_image) for epoch_image in epoch_images]

duration = 0.15
images[0].save(gif_filename,
            format='GIF',
            append_images=images[1:],
            save_all=True,
            duration=duration*1000,
            loop=0)

# Delete the individual epoch images
for epoch_image in epoch_images:
    os.remove(epoch_image)

# %%
# Display the GIF
Image(filename=gif_filename)
